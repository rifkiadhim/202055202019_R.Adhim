# %% [markdown]
# <a href="https://colab.research.google.com/github/rifkiadhim/202055202019_R.Adhim/blob/master/DEEP_POTHOLES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.3/78.2 GB disk)

# %%
from google.colab import drive
drive.mount ("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip "/content/drive/MyDrive/jalanberlubang.zip"
# Out:
# Archive:  /content/drive/MyDrive/jalanberlubang.zip
#    creating: jalanberlubang/test/
#    creating: jalanberlubang/test/images/
#   inflating: jalanberlubang/test/images/jalanrusak1_001_png.rf.7b22dfb363354ed08536a19f43f5ba90.jpg
#   inflating: jalanberlubang/test/images/jalanrusak1_037_png.rf.1fdba3aafa7f2a9dac9b5c52589b9c09.jpg
#   inflating: jalanberlubang/test/images/jalanrusak1_038_png.rf.9deea33ee3ab57ba1bbf9ddb347a8882.jpg
#   inflating: jalanberlubang/test/images/jalanrusak2_001_png.rf.caeca5fa0b5f5dccb66afceaee0e3079.jpg
#   inflating: jalanberlubang/test/images/jalanrusak2_042_png.rf.eefb095682206893906690fb89e0a7e9.jpg
#   inflating: jalanberlubang/test/images/jalanrusak4_004_png.rf.df8a8b48b9059c2aed9a4a4b4adcdb2f.jpg
#   inflating: jalanberlubang/test/images/jalanrusak4_022_png.rf.0bae3c012030d4b021da7fe0619507ee.jpg
#   inflating: jalanberlubang/test/images/jalanrusak5_001_png.rf.a7b8af87de57403646678eb8b52ad99e.jpg
# ...

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/yolov5/data/data.yaml --weights yolov5s.pt --cache
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.10 --source /content/drive/MyDrive/foto/1.jpg

# %%
cp /content/drive/MyDrive/foto/1.jpg /content/drive/MyDrive
